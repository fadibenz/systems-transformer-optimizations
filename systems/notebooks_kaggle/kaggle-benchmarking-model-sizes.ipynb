# %% [markdown]
# # Benchmarking different model sizes:
# This is notebook for running benchamrking steps on different model sizes and hyperparametes

# %% [markdown]
# ## Code loading and setup:

# %%
# !rm -rf "/kaggle/working/systems-transformer-optimizations"

# %%
# %cd "/kaggle/working/"
# Out:
# /kaggle/working

# %%
# !git clone https://github.com/fadibenz/systems-transformer-optimizations
# Out:
# Cloning into 'systems-transformer-optimizations'...
# remote: Enumerating objects: 67, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 67 (delta 17), reused 64 (delta 14), pack-reused 0 (from 0)
# Receiving objects: 100% (67/67), 796.85 KiB | 14.23 MiB/s, done.
# Resolving deltas: 100% (17/17), done.

# %%
# %cd "/kaggle/working/systems-transformer-optimizations"
# Out:
# /kaggle/working/systems-transformer-optimizations

# %% [markdown]
# ## Requirements installation:

# %%
# %cd "/kaggle/working/systems-transformer-optimizations/transformer_implementation"
# !pip install -e .
# Out:
# /kaggle/working/systems-transformer-optimizations/transformer_implementation
# Obtaining file:///kaggle/working/systems-transformer-optimizations/transformer_implementation
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for transformer_implementation (pyproject.toml) ... done
#   Created wheel for transformer_implementation: filename=transformer_implementation-1.0.0-0.editable-py3-none-any.whl size=3426 sha256=712be212a308d2df9777b68ce84eb39b1ebbd0c37c5772b3e71fbf58a23323cb
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dwaecw07/wheels/09/f4/e3/2558e413bda24d78b292775d12902f6560e132ab999cbecc95
# Successfully built transformer_implementation
# ...
#   Attempting uninstall: transformer_implementation
#     Found existing installation: transformer_implementation 1.0.0
# ...

# %%
# %cd "/kaggle/working/systems-transformer-optimizations"
# !pip install -e .
# Out:
# /kaggle/working/systems-transformer-optimizations
# Obtaining file:///kaggle/working/systems-transformer-optimizations
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for systems (pyproject.toml) ... done
#   Created wheel for systems: filename=systems-1.0.4-0.editable-py3-none-any.whl size=3456 sha256=f0658b38bd727d39dc5bfd3d288bf0b9a6608748f3067f8d6bbfa7634cbf4b4d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-uewuw688/wheels/38/cb/41/2dc572caa183246f6373f3dad8566abe6825953402bac7fa1e
# Successfully built systems
# ...
#   Attempting uninstall: systems
#     Found existing installation: systems 1.0.4
#     Uninstalling systems-1.0.4:
#       Successfully uninstalled systems-1.0.4
# ...

# %% [markdown]
# ## Run Script:

# %%
# !python /kaggle/working/systems-transformer-optimizations/systems/1_benchmarking_profiling/benchmarking_script.py --model xl --context_length 128 --iters 10 --warmup_iters 2 --seed 2027
# Out:
#  ----Started benchmarking----
# Running on device: cuda (Tesla P100-PCIE-16GB)
#
#  ----Finished benchmarking----
#
#  it took 0.17859162009999635s to run forward pass on model of size xl with standard deviation 0.00169957316707849s
